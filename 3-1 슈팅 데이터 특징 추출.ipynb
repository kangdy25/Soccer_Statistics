# %% [markdown]
# ### 강의에서 소개된 파이썬 주요 기능
# - numpy.linalg.norm: https://numpy.org/doc/stable/reference/generated/numpy.linalg.norm.html
# - numpy.arctan: https://numpy.org/doc/stable/reference/generated/numpy.arctan.html
# - numpy.where: https://numpy.org/doc/stable/reference/generated/numpy.where.html

# %% [markdown]
# ### 전경기 슈팅 데이터 불러오기

# %%
import os
import numpy as np
import pandas as pd
from tqdm import tqdm

# %% [markdown]
# ##### (1) 이벤트 데이터 불러오기

# %%
competitions = [x for x in os.listdir('data/refined_events') if not x.startswith('.')]
match_events_list = []

for competition_name in competitions:
    match_df = pd.read_csv(f'data/refined_events/{competition_name}/matches.csv', index_col=0, encoding='utf-8-sig')

    for match_id in tqdm(match_df.index, desc=f"{competition_name + ' ':10s}"):
        match_events = pd.read_pickle(f'data/refined_events/{competition_name}/{match_id}.pkl')
        match_events['competition_name'] = competition_name
        match_events_list.append(match_events)

events = pd.concat(match_events_list, ignore_index=True)
events
# Out:
# England   : 100%|███████████████████████████████████████████████████████████████████| 380/380 [00:01<00:00, 213.84it/s]
# European_Championship : 100%|█████████████████████████████████████████████████████████| 51/51 [00:00<00:00, 209.88it/s]
# France    : 100%|███████████████████████████████████████████████████████████████████| 380/380 [00:01<00:00, 233.13it/s]
# Germany   : 100%|███████████████████████████████████████████████████████████████████| 306/306 [00:01<00:00, 212.05it/s]
# Italy     : 100%|███████████████████████████████████████████████████████████████████| 380/380 [00:01<00:00, 233.42it/s]
# Spain     : 100%|███████████████████████████████████████████████████████████████████| 380/380 [00:01<00:00, 227.95it/s]
# World_Cup : 100%|█████████████████████████████████████████████████████████████████████| 64/64 [00:00<00:00, 243.34it/s]
#         match_id   event_id period      time team_id team_name player_id  \
# 0        2499719  177959171     1H     2.759    1609   Arsenal     25413
# 1        2499719  177959172     1H     4.947    1609   Arsenal    370224
# 2        2499719  177959173     1H     6.542    1609   Arsenal      3319
# 3        2499719  177959174     1H     8.143    1609   Arsenal    120339
# 4        2499719  177959175     1H    10.302    1609   Arsenal    167145
# ...          ...        ...    ...       ...     ...       ...       ...
# 3273243  2058017  263885652     2H  2978.302    9598   Croatia      3476
# 3273244  2058017  263885653     2H  2979.085    9598   Croatia     14812
# 3273245  2058017  263885654     2H  2983.449    9598   Croatia     14812
# 3273246  2058017  263885613     2H  2985.869    4418    France     25381
# 3273247  2058017  263885618     2H  3002.149    4418    France     25381
#
#             player_name               event_type           sub_event_type  \
# 0          A. Lacazette                     Pass              Simple pass
# 1            R. Holding                     Pass                High pass
# 2               M. Özil                     Pass                Head pass
# 3        Mohamed Elneny                     Pass                Head pass
# 4              Bellerín                     Pass              Simple pass
# ...                 ...                      ...                      ...
# 3273243      I. Rakitić                     Pass              Simple pass
# 3273244      I. Perišić       Others on the ball                    Touch
# 3273245      I. Perišić                     Pass                    Cross
# 3273246       H. Lloris  Goalkeeper leaving line  Goalkeeper leaving line
# 3273247       H. Lloris                     Pass                   Launch
#
#                                     tags  start_x  start_y   end_x  end_y  \
# 0                             [Accurate]    50.96    34.68   32.24  14.96
# 1                             [Accurate]    32.24    14.96   53.04  17.00
# 2                             [Accurate]    53.04    17.00   36.40  19.72
# 3                             [Accurate]    36.40    19.72   42.64   3.40
# 4                             [Accurate]    42.64     3.40   74.88   8.16
# ...                                  ...      ...      ...     ...    ...
# 3273243                       [Accurate]    47.84    54.40   66.56  63.92
# 3273244                               []    66.56    63.92   85.28  66.64
# 3273245  [Left foot, High, Not accurate]    85.28    66.64  104.00  34.00
# 3273246                               []     0.00    34.00   14.56  38.76
# 3273247                   [Not accurate]    14.56    38.76     NaN    NaN
#
#         competition_name
# 0                England
# 1                England
# 2                England
# 3                England
# 4                England
# ...                  ...
# 3273243        World_Cup
# 3273244        World_Cup
# 3273245        World_Cup
# 3273246        World_Cup
# 3273247        World_Cup
#
# [3273248 rows x 16 columns]

# %% [markdown]
# ##### (2) 슈팅 데이터 필터링

# %%
shots = events[
    (events['event_type'] == 'Shot') | (events['sub_event_type'].isin(['Free kick shot', 'Penalty']))
].reset_index(drop=True)
shots
# Out:
#       match_id   event_id period      time team_id       team_name player_id  \
# 0      2499719  177959212     1H    94.596    1609         Arsenal     25413
# 1      2499719  177959247     1H   179.855    1631  Leicester City     26150
# 2      2499719  177959280     1H   254.745    1631  Leicester City     14763
# 3      2499719  177959289     1H   425.824    1609         Arsenal      7868
# 4      2499719  177959429     1H   815.462    1609         Arsenal      7868
# ...        ...        ...    ...       ...     ...             ...       ...
# 45940  2058017  263885208     2H  1389.183    9598         Croatia     14943
# 45941  2058017  263885299     2H  1802.299    9598         Croatia     69409
# 45942  2058017  263885348     2H  1933.996    9598         Croatia      3476
# 45943  2058017  263885485     2H  2487.443    4418          France     28115
# 45944  2058017  263885575     2H  2589.084    9598         Croatia      3476
#
#                  player_name event_type sub_event_type  \
# 0               A. Lacazette       Shot           Shot
# 1                  R. Mahrez       Shot           Shot
# 2                 S. Okazaki       Shot           Shot
# 3      A. Oxlade-Chamberlain       Shot           Shot
# 4      A. Oxlade-Chamberlain       Shot           Shot
# ...                      ...        ...            ...
# 45940           M. Mandžukić       Shot           Shot
# 45941            Š. Vrsaljko       Shot           Shot
# 45942             I. Rakitić       Shot           Shot
# 45943               N. Fekir       Shot           Shot
# 45944             I. Rakitić       Shot           Shot
#
#                                                     tags  start_x  start_y  \
# 0      [Goal, Right foot, Opportunity, Position: Goal...    91.52    40.12
# 1      [Left foot, Opportunity, Position: Out center ...    88.40    32.64
# 2      [Goal, Head/body, Opportunity, Position: Goal ...    99.84    32.64
# 3      [Left foot, Opportunity, Position: Out high le...    84.24    45.56
# 4      [Right foot, Opportunity, Position: Goal low l...    78.00    47.60
# ...                                                  ...      ...      ...
# 45940  [Goal, Right foot, Opportunity, Position: Goal...    95.68    31.96
# 45941  [Right foot, Opportunity, Position: Out center...    67.60    26.52
# 45942                 [Left foot, Blocked, Not accurate]    84.24    45.56
# 45943  [Left foot, Opportunity, Position: Goal center...    81.12    16.32
# 45944  [Right foot, Opportunity, Position: Out high r...    72.80    48.28
#
#        end_x  end_y competition_name
# 0      104.0  34.00          England
# 1      104.0  34.00          England
# 2      104.0  34.00          England
# 3      104.0  34.00          England
# 4      104.0  34.00          England
# ...      ...    ...              ...
# 45940  104.0  34.00        World_Cup
# 45941  104.0  34.00        World_Cup
# 45942   93.6  43.52        World_Cup
# 45943  104.0  34.00        World_Cup
# 45944  104.0  34.00        World_Cup
#
# [45945 rows x 16 columns]

# %% [markdown]
# ### 슈팅별 특징 추출

# %% [markdown]
# ##### (1) 슈팅 위치 및 거리 계산

# %%
shot_features = pd.DataFrame(index=shots.index)
shot_features['x'] = 104 - shots['start_x']
shot_features['y'] = shots['start_y'] - 34
shot_features['distance'] = shot_features[['x', 'y']].apply(np.linalg.norm, axis=1)
shot_features
# Out:
#            x      y   distance
# 0      12.48   6.12  13.899813
# 1      15.60  -1.36  15.659170
# 2       4.16  -1.36   4.376665
# 3      19.76  11.56  22.893038
# 4      26.00  13.60  29.342120
# ...      ...    ...        ...
# 45940   8.32  -2.04   8.566446
# 45941  36.40  -7.48  37.160603
# 45942  19.76  11.56  22.893038
# 45943  22.88 -17.68  28.914993
# 45944  31.20  14.28  34.312657
#
# [45945 rows x 3 columns]

# %% [markdown]
# ##### (2) 슈팅 각도 계산

# %%
x = shot_features['x']
y = shot_features['y']
goal_width = 7.32
angles = np.arctan((goal_width * x) / (x ** 2 + y ** 2 - (goal_width / 2) ** 2)) * 180 / np.pi
shot_features['angle'] = np.where(angles >= 0, angles, angles + 180)
shot_features
# Out:
#            x      y   distance      angle
# 0      12.48   6.12  13.899813  26.933236
# 1      15.60  -1.36  15.659170  26.224941
# 2       4.16  -1.36   4.376665  79.289489
# 3      19.76  11.56  22.893038  15.813597
# 4      26.00  13.60  29.342120  12.655803
# ...      ...    ...        ...        ...
# 45940   8.32  -2.04   8.566446  45.433179
# 45941  36.40  -7.48  37.160603  11.025434
# 45942  19.76  11.56  22.893038  15.813597
# 45943  22.88 -17.68  28.914993  11.507036
# 45944  31.20  14.28  34.312657  11.101118
#
# [45945 rows x 4 columns]

# %% [markdown]
# ##### (3) 슈팅 유형 및 득점 여부 추출

# %%
shot_features['freekick'] = (shots['event_type'] == 'Free kick').astype(int)
shot_features['header'] = shots['tags'].apply(lambda x: 'Head/body' in x).astype(int)
shot_features['goal'] = shots['tags'].apply(lambda x: 'Goal' in x).astype(int)
shot_features
# Out:
#            x      y   distance      angle  freekick  header  goal
# 0      12.48   6.12  13.899813  26.933236         0       0     1
# 1      15.60  -1.36  15.659170  26.224941         0       0     0
# 2       4.16  -1.36   4.376665  79.289489         0       1     1
# 3      19.76  11.56  22.893038  15.813597         0       0     0
# 4      26.00  13.60  29.342120  12.655803         0       0     0
# ...      ...    ...        ...        ...       ...     ...   ...
# 45940   8.32  -2.04   8.566446  45.433179         0       0     1
# 45941  36.40  -7.48  37.160603  11.025434         0       0     0
# 45942  19.76  11.56  22.893038  15.813597         0       0     0
# 45943  22.88 -17.68  28.914993  11.507036         0       0     0
# 45944  31.20  14.28  34.312657  11.101118         0       0     0
#
# [45945 rows x 7 columns]

# %% [markdown]
# ##### (4) 슈팅 데이터 연결 및 저장

# %%
shots = pd.concat([shots[['competition_name'] + shots.columns[:-5].tolist()], shot_features], axis=1)
shots
# Out:
#       competition_name match_id   event_id period      time team_id  \
# 0              England  2499719  177959212     1H    94.596    1609
# 1              England  2499719  177959247     1H   179.855    1631
# 2              England  2499719  177959280     1H   254.745    1631
# 3              England  2499719  177959289     1H   425.824    1609
# 4              England  2499719  177959429     1H   815.462    1609
# ...                ...      ...        ...    ...       ...     ...
# 45940        World_Cup  2058017  263885208     2H  1389.183    9598
# 45941        World_Cup  2058017  263885299     2H  1802.299    9598
# 45942        World_Cup  2058017  263885348     2H  1933.996    9598
# 45943        World_Cup  2058017  263885485     2H  2487.443    4418
# 45944        World_Cup  2058017  263885575     2H  2589.084    9598
#
#             team_name player_id            player_name event_type  \
# 0             Arsenal     25413           A. Lacazette       Shot
# 1      Leicester City     26150              R. Mahrez       Shot
# 2      Leicester City     14763             S. Okazaki       Shot
# 3             Arsenal      7868  A. Oxlade-Chamberlain       Shot
# 4             Arsenal      7868  A. Oxlade-Chamberlain       Shot
# ...               ...       ...                    ...        ...
# 45940         Croatia     14943           M. Mandžukić       Shot
# 45941         Croatia     69409            Š. Vrsaljko       Shot
# 45942         Croatia      3476             I. Rakitić       Shot
# 45943          France     28115               N. Fekir       Shot
# 45944         Croatia      3476             I. Rakitić       Shot
#
#       sub_event_type                                               tags  \
# 0               Shot  [Goal, Right foot, Opportunity, Position: Goal...
# 1               Shot  [Left foot, Opportunity, Position: Out center ...
# 2               Shot  [Goal, Head/body, Opportunity, Position: Goal ...
# 3               Shot  [Left foot, Opportunity, Position: Out high le...
# 4               Shot  [Right foot, Opportunity, Position: Goal low l...
# ...              ...                                                ...
# 45940           Shot  [Goal, Right foot, Opportunity, Position: Goal...
# 45941           Shot  [Right foot, Opportunity, Position: Out center...
# 45942           Shot                 [Left foot, Blocked, Not accurate]
# 45943           Shot  [Left foot, Opportunity, Position: Goal center...
# 45944           Shot  [Right foot, Opportunity, Position: Out high r...
#
#            x      y   distance      angle  freekick  header  goal
# 0      12.48   6.12  13.899813  26.933236         0       0     1
# 1      15.60  -1.36  15.659170  26.224941         0       0     0
# 2       4.16  -1.36   4.376665  79.289489         0       1     1
# 3      19.76  11.56  22.893038  15.813597         0       0     0
# 4      26.00  13.60  29.342120  12.655803         0       0     0
# ...      ...    ...        ...        ...       ...     ...   ...
# 45940   8.32  -2.04   8.566446  45.433179         0       0     1
# 45941  36.40  -7.48  37.160603  11.025434         0       0     0
# 45942  19.76  11.56  22.893038  15.813597         0       0     0
# 45943  22.88 -17.68  28.914993  11.507036         0       0     0
# 45944  31.20  14.28  34.312657  11.101118         0       0     0
#
# [45945 rows x 19 columns]

# %%
shots.to_pickle('data/shots.pkl')
