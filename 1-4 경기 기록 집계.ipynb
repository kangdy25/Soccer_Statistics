# %% [markdown]
# ### 강의에서 사용된 파이썬 주요 기능

# %% [markdown]
# - 데이터 집계 기초
#   - pandas.Series.value_counts: https://pandas.pydata.org/docs/reference/api/pandas.Series.value_counts.html
#   - pandas.DataFrame.groupby: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.groupby.html
#   - pandas.DataFrame.pivot_table: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.pivot_table.html

# %% [markdown]
# - 이벤트 성공 여부 집계
#   - pandas.DataFrame.apply: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.apply.html
#   - Lambda functions: https://wikidocs.net/22804

# %% [markdown]
# ### 경기 데이터 불러오기

# %%
import pandas as pd

# %%
match_id = 2058017
match_events = pd.read_pickle(f'data/refined_events/World_Cup/{match_id}.pkl')
match_events
# Out:
#      match_id   event_id period      time team_id team_name player_id  \
# 0     2058017  263883958     1H     1.892    9598   Croatia     14943
# 1     2058017  263883959     1H     3.889    9598   Croatia     69968
# 2     2058017  263883960     1H     6.141    9598   Croatia      8287
# 3     2058017  263883963     1H     9.227    9598   Croatia     69409
# 4     2058017  263883964     1H    12.659    9598   Croatia    135747
# ...       ...        ...    ...       ...     ...       ...       ...
# 1467  2058017  263885652     2H  2978.302    9598   Croatia      3476
# 1468  2058017  263885653     2H  2979.085    9598   Croatia     14812
# 1469  2058017  263885654     2H  2983.449    9598   Croatia     14812
# 1470  2058017  263885613     2H  2985.869    4418    France     25381
# 1471  2058017  263885618     2H  3002.149    4418    France     25381
#
#        player_name               event_type           sub_event_type  \
# 0     M. Mandžukić                     Pass              Simple pass
# 1      M. Brozović                     Pass              Simple pass
# 2        L. Modrić                     Pass              Simple pass
# 3      Š. Vrsaljko                     Pass              Simple pass
# 4       D. Subašić                     Pass                   Launch
# ...            ...                      ...                      ...
# 1467    I. Rakitić                     Pass              Simple pass
# 1468    I. Perišić       Others on the ball                    Touch
# 1469    I. Perišić                     Pass                    Cross
# 1470     H. Lloris  Goalkeeper leaving line  Goalkeeper leaving line
# 1471     H. Lloris                     Pass                   Launch
#
#                                  tags  start_x  start_y   end_x  end_y
# 0                                  []    52.00    33.32     NaN    NaN
# 1                          [Accurate]    40.56    32.64   35.36  17.68
# 2                          [Accurate]    35.36    17.68   31.20   4.76
# 3                          [Accurate]    31.20     4.76   11.44  23.80
# 4                          [Accurate]    11.44    23.80   66.56  33.32
# ...                               ...      ...      ...     ...    ...
# 1467                       [Accurate]    47.84    54.40   66.56  63.92
# 1468                               []    66.56    63.92   85.28  66.64
# 1469  [Left foot, High, Not accurate]    85.28    66.64  104.00  34.00
# 1470                               []     0.00    34.00   14.56  38.76
# 1471                   [Not accurate]    14.56    38.76     NaN    NaN
#
# [1472 rows x 15 columns]

# %% [markdown]
# ### 데이터 집계 기초

# %% [markdown]
# ##### (1) Series.value_counts 함수를 활용한 항목별 횟수 집계

# %% [markdown]
# - 팀별 슈팅 횟수

# %%
shot_records = match_events[
    (match_events['event_type'] == 'Shot') |
    (match_events['sub_event_type'].isin(['Free kick shot', 'Penalty']))
]
shot_records['team_name'].value_counts()
# Out:
# Croatia    14
# France      8
# Name: team_name, dtype: int64

# %% [markdown]
# - 선수별 패스 횟수

# %%
pass_records = match_events[
    (match_events['event_type'] == 'Pass') |
    (match_events['sub_event_type'].isin(['Free kick', 'Free kick cross', 'corner']))
]
pass_records['player_name'].value_counts()
# Out:
# M. Brozović     93
# L. Modrić       72
# D. Lovren       65
# I. Rakitić      63
# Š. Vrsaljko     62
# D. Vida         46
# I. Perišić      35
# P. Pogba        31
# M. Mandžukić    29
# R. Varane       25
# I. Strinić      25
# A. Griezmann    24
# B. Matuidi      22
# O. Giroud       21
# S. Umtiti       21
# L. Hernández    20
# B. Pavard       20
# H. Lloris       18
# K. Mbappé       14
# A. Rebić        14
# S. N'Zonzi      14
# N. Kanté        13
# D. Subašić      13
# A. Kramarić     10
# C. Tolisso       7
# N. Fekir         2
# M. Pjaca         2
# Name: player_name, dtype: int64

# %% [markdown]
# ##### (2) DataFrame.groupby 함수를 활용한 항목별 연산

# %% [markdown]
# - 전후반 경기 시간

# %%
match_events.groupby('period')['time'].max()
# Out:
# period
# 1H    2905.875
# 2H    3002.149
# Name: time, dtype: float64

# %% [markdown]
# - 팀별 패스 발생 및 종료 위치

# %%
pass_records.groupby('team_name')[['start_x', 'start_y', 'end_x', 'end_y']].mean()
# Out:
#              start_x    start_y    end_x      end_y
# team_name
# Croatia    52.436446  31.492098  58.6300  31.055909
# France     43.911111  35.848413  53.2064  35.308320

# %% [markdown]
# - 각 이벤트 유형의 팀별 발생 횟수

# %%
match_events.groupby(['team_name', 'event_type'])['event_id'].count()
# Out:
# team_name  event_type
# Croatia    Duel                       194
#            Foul                        13
#            Free kick                   42
#            Offside                      1
#            Others on the ball          72
#            Pass                       518
#            Save attempt                 7
#            Shot                        14
#            Substitution                 4
# France     Duel                       194
#            Foul                        13
#            Free kick                   51
#            Goalkeeper leaving line      5
#            Offside                      1
#            Others on the ball          86
#            Pass                       241
#            Save attempt                 3
#            Shot                         7
#            Substitution                 6
# Name: event_id, dtype: int64

# %% [markdown]
# ##### (3) pandas.pivot_table 함수를 활용한 다차원 집계

# %% [markdown]
# - 각 이벤트 유형의 팀별 발생 횟수

# %%
match_events.pivot_table(values='event_id', index='event_type', columns='team_name', aggfunc='count')
# Out:
# team_name                Croatia  France
# event_type
# Duel                       194.0   194.0
# Foul                        13.0    13.0
# Free kick                   42.0    51.0
# Goalkeeper leaving line      NaN     5.0
# Offside                      1.0     1.0
# Others on the ball          72.0    86.0
# Pass                       518.0   241.0
# Save attempt                 7.0     3.0
# Shot                        14.0     7.0
# Substitution                 4.0     6.0

# %%
counts = match_events.pivot_table('event_id', 'event_type', 'team_name', 'count', fill_value=0)
counts.sort_values('France', ascending=False)
# Out:
# team_name                Croatia  France
# event_type
# Pass                         518     241
# Duel                         194     194
# Others on the ball            72      86
# Free kick                     42      51
# Foul                          13      13
# Shot                          14       7
# Substitution                   4       6
# Goalkeeper leaving line        0       5
# Save attempt                   7       3
# Offside                        1       1

# %% [markdown]
# ### 이벤트 성공 여부 집계

# %%
pass_records = match_events[
    (match_events['event_type'] == 'Pass') |
    (match_events['sub_event_type'].isin(['Free kick', 'Free kick cross', 'corner']))
]
pass_records.head()
# Out:
#   match_id   event_id period    time team_id team_name player_id  \
# 0  2058017  263883958     1H   1.892    9598   Croatia     14943
# 1  2058017  263883959     1H   3.889    9598   Croatia     69968
# 2  2058017  263883960     1H   6.141    9598   Croatia      8287
# 3  2058017  263883963     1H   9.227    9598   Croatia     69409
# 4  2058017  263883964     1H  12.659    9598   Croatia    135747
#
#     player_name event_type sub_event_type        tags  start_x  start_y  \
# 0  M. Mandžukić       Pass    Simple pass          []    52.00    33.32
# 1   M. Brozović       Pass    Simple pass  [Accurate]    40.56    32.64
# 2     L. Modrić       Pass    Simple pass  [Accurate]    35.36    17.68
# 3   Š. Vrsaljko       Pass    Simple pass  [Accurate]    31.20     4.76
# 4    D. Subašić       Pass         Launch  [Accurate]    11.44    23.80
#
#    end_x  end_y
# 0    NaN    NaN
# 1  35.36  17.68
# 2  31.20   4.76
# 3  11.44  23.80
# 4  66.56  33.32

# %% [markdown]
# ##### (1) 반복문 기반 성공 여부 판단

# %%
success_idx = []
for i in pass_records.index:
    tags = pass_records.at[i, 'tags']
    if 'Accurate' in tags:
        success_idx.append(i)

acc_pass_records = pass_records.loc[success_idx]
acc_pass_records
# Out:
#      match_id   event_id period      time team_id team_name player_id  \
# 1     2058017  263883959     1H     3.889    9598   Croatia     69968
# 2     2058017  263883960     1H     6.141    9598   Croatia      8287
# 3     2058017  263883963     1H     9.227    9598   Croatia     69409
# 4     2058017  263883964     1H    12.659    9598   Croatia    135747
# 7     2058017  263883967     1H    18.364    9598   Croatia     14812
# ...       ...        ...    ...       ...     ...       ...       ...
# 1448  2058017  263885639     2H   2886.43    9598   Croatia     69968
# 1449  2058017  263885640     2H  2888.451    9598   Croatia     69411
# 1453  2058017  263885642     2H  2897.301    9598   Croatia     69396
# 1454  2058017  263885644     2H  2900.174    9598   Croatia      3476
# 1467  2058017  263885652     2H  2978.302    9598   Croatia      3476
#
#       player_name event_type sub_event_type        tags  start_x  start_y  \
# 1     M. Brozović       Pass    Simple pass  [Accurate]    40.56    32.64
# 2       L. Modrić       Pass    Simple pass  [Accurate]    35.36    17.68
# 3     Š. Vrsaljko       Pass    Simple pass  [Accurate]    31.20     4.76
# 4      D. Subašić       Pass         Launch  [Accurate]    11.44    23.80
# 7      I. Perišić       Pass    Simple pass  [Accurate]    65.52    54.40
# ...           ...        ...            ...         ...      ...      ...
# 1448  M. Brozović       Pass    Simple pass  [Accurate]    64.48    57.12
# 1449  A. Kramarić       Pass    Simple pass  [Accurate]    76.96    60.52
# 1453      D. Vida       Pass    Simple pass  [Accurate]    48.88    65.28
# 1454   I. Rakitić       Pass    Simple pass  [Accurate]    61.36    51.00
# 1467   I. Rakitić       Pass    Simple pass  [Accurate]    47.84    54.40
#
#       end_x  end_y
# 1     35.36  17.68
# 2     31.20   4.76
# 3     11.44  23.80
# 4     66.56  33.32
# 7     53.04  56.44
# ...     ...    ...
# 1448  76.96  60.52
# 1449  88.40  64.60
# 1453  61.36  51.00
# 1454  69.68  55.76
# 1467  66.56  63.92
#
# [629 rows x 15 columns]

# %% [markdown]
# ##### (2) DataFrame.apply 함수 기반 성공 여부 판단

# %%
def is_accurate(tags):
    return 'Accurate' in tags

# %%
pass_records['tags'].apply(is_accurate)
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1454     True
# 1464    False
# 1467     True
# 1469    False
# 1471    False
# Name: tags, Length: 781, dtype: bool

# %%
acc_pass_records = pass_records[pass_records['tags'].apply(is_accurate)]
acc_pass_records
# Out:
#      match_id   event_id period      time team_id team_name player_id  \
# 1     2058017  263883959     1H     3.889    9598   Croatia     69968
# 2     2058017  263883960     1H     6.141    9598   Croatia      8287
# 3     2058017  263883963     1H     9.227    9598   Croatia     69409
# 4     2058017  263883964     1H    12.659    9598   Croatia    135747
# 7     2058017  263883967     1H    18.364    9598   Croatia     14812
# ...       ...        ...    ...       ...     ...       ...       ...
# 1448  2058017  263885639     2H   2886.43    9598   Croatia     69968
# 1449  2058017  263885640     2H  2888.451    9598   Croatia     69411
# 1453  2058017  263885642     2H  2897.301    9598   Croatia     69396
# 1454  2058017  263885644     2H  2900.174    9598   Croatia      3476
# 1467  2058017  263885652     2H  2978.302    9598   Croatia      3476
#
#       player_name event_type sub_event_type        tags  start_x  start_y  \
# 1     M. Brozović       Pass    Simple pass  [Accurate]    40.56    32.64
# 2       L. Modrić       Pass    Simple pass  [Accurate]    35.36    17.68
# 3     Š. Vrsaljko       Pass    Simple pass  [Accurate]    31.20     4.76
# 4      D. Subašić       Pass         Launch  [Accurate]    11.44    23.80
# 7      I. Perišić       Pass    Simple pass  [Accurate]    65.52    54.40
# ...           ...        ...            ...         ...      ...      ...
# 1448  M. Brozović       Pass    Simple pass  [Accurate]    64.48    57.12
# 1449  A. Kramarić       Pass    Simple pass  [Accurate]    76.96    60.52
# 1453      D. Vida       Pass    Simple pass  [Accurate]    48.88    65.28
# 1454   I. Rakitić       Pass    Simple pass  [Accurate]    61.36    51.00
# 1467   I. Rakitić       Pass    Simple pass  [Accurate]    47.84    54.40
#
#       end_x  end_y
# 1     35.36  17.68
# 2     31.20   4.76
# 3     11.44  23.80
# 4     66.56  33.32
# 7     53.04  56.44
# ...     ...    ...
# 1448  76.96  60.52
# 1449  88.40  64.60
# 1453  61.36  51.00
# 1454  69.68  55.76
# 1467  66.56  63.92
#
# [629 rows x 15 columns]

# %% [markdown]
# ##### (3) 람다 표현식(lambda expression) 기반 성공 여부 판단

# %%
acc_pass_records = pass_records[pass_records['tags'].apply(lambda x: 'Accurate' in x)]
acc_pass_records
# Out:
#      match_id   event_id period      time team_id team_name player_id  \
# 1     2058017  263883959     1H     3.889    9598   Croatia     69968
# 2     2058017  263883960     1H     6.141    9598   Croatia      8287
# 3     2058017  263883963     1H     9.227    9598   Croatia     69409
# 4     2058017  263883964     1H    12.659    9598   Croatia    135747
# 7     2058017  263883967     1H    18.364    9598   Croatia     14812
# ...       ...        ...    ...       ...     ...       ...       ...
# 1448  2058017  263885639     2H   2886.43    9598   Croatia     69968
# 1449  2058017  263885640     2H  2888.451    9598   Croatia     69411
# 1453  2058017  263885642     2H  2897.301    9598   Croatia     69396
# 1454  2058017  263885644     2H  2900.174    9598   Croatia      3476
# 1467  2058017  263885652     2H  2978.302    9598   Croatia      3476
#
#       player_name event_type sub_event_type        tags  start_x  start_y  \
# 1     M. Brozović       Pass    Simple pass  [Accurate]    40.56    32.64
# 2       L. Modrić       Pass    Simple pass  [Accurate]    35.36    17.68
# 3     Š. Vrsaljko       Pass    Simple pass  [Accurate]    31.20     4.76
# 4      D. Subašić       Pass         Launch  [Accurate]    11.44    23.80
# 7      I. Perišić       Pass    Simple pass  [Accurate]    65.52    54.40
# ...           ...        ...            ...         ...      ...      ...
# 1448  M. Brozović       Pass    Simple pass  [Accurate]    64.48    57.12
# 1449  A. Kramarić       Pass    Simple pass  [Accurate]    76.96    60.52
# 1453      D. Vida       Pass    Simple pass  [Accurate]    48.88    65.28
# 1454   I. Rakitić       Pass    Simple pass  [Accurate]    61.36    51.00
# 1467   I. Rakitić       Pass    Simple pass  [Accurate]    47.84    54.40
#
#       end_x  end_y
# 1     35.36  17.68
# 2     31.20   4.76
# 3     11.44  23.80
# 4     66.56  33.32
# 7     53.04  56.44
# ...     ...    ...
# 1448  76.96  60.52
# 1449  88.40  64.60
# 1453  61.36  51.00
# 1454  69.68  55.76
# 1467  66.56  63.92
#
# [629 rows x 15 columns]

# %% [markdown]
# ### 경기 통계 정리

# %% [markdown]
# ##### (1) 패스 성공률 산출

# %%
total_pass_counts = pass_records['team_name'].value_counts().rename('total_passes')
acc_pass_counts = acc_pass_records['team_name'].value_counts().rename('acc_passes')
pass_counts = pd.concat([total_pass_counts, acc_pass_counts], axis=1)
pass_counts
# Out:
#          total_passes  acc_passes
# Croatia           529         436
# France            252         193

# %%
pass_counts['pass_accuracy'] = pass_counts['acc_passes'] / pass_counts['total_passes']
pass_counts
# Out:
#          total_passes  acc_passes  pass_accuracy
# Croatia           529         436       0.824197
# France            252         193       0.765873

# %% [markdown]
# ##### (2) 유효 슈팅 횟수 집계

# %%
shot_records = match_events[
    (match_events['event_type'] == 'Shot') |
    (match_events['sub_event_type'].isin(['Free kick shot', 'Penalty']))
]
acc_shot_records = shot_records[shot_records['tags'].apply(lambda x: 'Accurate' in x)]

total_shot_counts = shot_records['team_name'].value_counts().rename('total_shots')
acc_shot_counts = acc_shot_records['team_name'].value_counts().rename('shots_on_target')
shot_counts = pd.concat([total_shot_counts, acc_shot_counts], axis=1)
shot_counts
# Out:
#          total_shots  shots_on_target
# Croatia           14                3
# France             8                6

# %% [markdown]
# ##### (3) 득점 집계

# %% [markdown]
# - 득점 기록 필터링

# %%
match_events[match_events['tags'].apply(lambda x: 'Goal' in x)]
# Out:
#      match_id   event_id period      time team_id team_name player_id  \
# 434   2058017  263884397     1H   1676.03    9598   Croatia     14812
# 505   2058017  263884513     1H  2278.896    4418    France      3682
# 921   2058017  263885027     2H   816.147    4418    France      7936
# 1025  2058017  263885135     2H  1177.059    4418    France    353833
# 1076  2058017  263885208     2H  1389.183    9598   Croatia     14943
#
#        player_name event_type sub_event_type  \
# 434     I. Perišić       Shot           Shot
# 505   A. Griezmann  Free kick        Penalty
# 921       P. Pogba       Shot           Shot
# 1025     K. Mbappé       Shot           Shot
# 1076  M. Mandžukić       Shot           Shot
#
#                                                    tags  start_x  start_y  \
# 434   [Goal, Left foot, Opportunity, Position: Goal ...    90.48    39.44
# 505   [Goal, Left foot, Position: Goal low left, Acc...    92.56    34.68
# 921   [Goal, Left foot, Opportunity, Position: Goal ...    88.40    37.40
# 1025  [Goal, Right foot, Opportunity, Position: Goal...    78.00    29.92
# 1076  [Goal, Right foot, Opportunity, Position: Goal...    95.68    31.96
#
#       end_x  end_y
# 434   104.0   34.0
# 505   104.0   34.0
# 921   104.0   34.0
# 1025  104.0   34.0
# 1076  104.0   34.0

# %% [markdown]
# - 자책골 기록 필터링

# %%
match_events[match_events['tags'].apply(lambda x: 'Own goal' in x)]
# Out:
#     match_id   event_id period      time team_id team_name player_id  \
# 309  2058017  263884274     1H  1078.761    9598   Croatia     14943
#
#       player_name          event_type sub_event_type  \
# 309  M. Mandžukić  Others on the ball      Clearance
#
#                                    tags  start_x  start_y  end_x  end_y
# 309  [Own goal, Interception, Accurate]    11.44    26.52    0.0   34.0

# %% [markdown]
# - 자책골 포함 양팀 득점 집계

# %%
team_names = match_events['team_name'].unique()
goals = dict(zip(match_events['team_name'].unique(), [0, 0]))
goals
# Out:
# {'Croatia': 0, 'France': 0}

# %%
goal_records = match_events[match_events['tags'].apply(lambda x: 'Goal' in x)]
for i, event in goal_records.iterrows():
    goals[event['team_name']] += 1

own_goal_records = match_events[match_events['tags'].apply(lambda x: 'Own goal' in x)]
for i, event in own_goal_records.iterrows():
    opponent_name = [team for team in team_names if team != event['team_name']][0]
    goals[opponent_name] += 1

goals
# Out:
# {'Croatia': 2, 'France': 4}

# %% [markdown]
# ##### (4) 경기 통계 정리

# %%
counts
# Out:
# team_name                Croatia  France
# event_type
# Duel                         194     194
# Foul                          13      13
# Free kick                     42      51
# Goalkeeper leaving line        0       5
# Offside                        1       1
# Others on the ball            72      86
# Pass                         518     241
# Save attempt                   7       3
# Shot                          14       7
# Substitution                   4       6

# %%
foul_counts = counts.T[['Foul', 'Offside']]
foul_counts.columns = ['fouls', 'offsides']
foul_counts
# Out:
#            fouls  offsides
# team_name
# Croatia       13         1
# France        13         1

# %%
match_stats = pd.concat([pass_counts, shot_counts, foul_counts], axis=1)
match_stats
# Out:
#          total_passes  acc_passes  pass_accuracy  total_shots  \
# Croatia           529         436       0.824197           14
# France            252         193       0.765873            8
#
#          shots_on_target  fouls  offsides
# Croatia                3     13         1
# France                 6     13         1

# %%
pd.Series(goals)
# Out:
# Croatia    2
# France     4
# dtype: int64

# %%
match_stats['goals'] = pd.Series(goals)
match_stats = match_stats[[
    'goals', 'total_shots', 'shots_on_target',
    'fouls', 'offsides',
    'total_passes', 'acc_passes', 'pass_accuracy'
]]
match_stats
# Out:
#          goals  total_shots  shots_on_target  fouls  offsides  total_passes  \
# Croatia      2           14                3     13         1           529
# France       4            8                6     13         1           252
#
#          acc_passes  pass_accuracy
# Croatia         436       0.824197
# France          193       0.765873

# %% [markdown]
# ## Mission
# 2018 월드컵에서 여러분이 인상깊게 봤던 경기 하나를 선택해서, 경기 통계를 집계하여 댓글로 공유해 주세요 :)

# %%
# 프랑스 VS 아르헨티나 경기 분석
match_id = 2058003
match_events = pd.read_pickle(f'data/refined_events/World_Cup/{match_id}.pkl')
match_events
# Out:
#      match_id   event_id period      time team_id  team_name player_id  \
# 0     2058003  261065118     1H     1.303    4418     France      3682
# 1     2058003  261065119     1H     5.377    4418     France      3309
# 2     2058003  261065120     1H     7.508    4418     France     26010
# 3     2058003  261065122     1H     8.163   12274  Argentina     86722
# 4     2058003  261065121     1H     8.824    4418     France     26010
# ...       ...        ...    ...       ...     ...        ...       ...
# 1433  2058003  261066780     2H   2988.34   12274  Argentina      3314
# 1434  2058003  261066781     2H   2990.99   12274  Argentina      8325
# 1435  2058003  261066783     2H  2993.545   12274  Argentina    146459
# 1436  2058003  261066821     2H  2994.626   12274  Argentina      3314
# 1437  2058003  261066816     2H  3004.524    4418     France     25381
#
#         player_name event_type sub_event_type  \
# 0      A. Griezmann       Pass    Simple pass
# 1         R. Varane       Pass      High pass
# 2         O. Giroud       Duel       Air duel
# 3     N. Tagliafico       Duel       Air duel
# 4         O. Giroud       Foul           Foul
# ...             ...        ...            ...
# 1433    Á. di María       Pass      High pass
# 1434      S. Agüero       Pass    Simple pass
# 1435        M. Meza       Pass          Cross
# 1436    Á. di María       Shot           Shot
# 1437      H. Lloris  Free kick      Goal kick
#
#                                                    tags  start_x  start_y  \
# 0                                            [Accurate]    52.00    34.00
# 1                                            [Accurate]    34.32    21.08
# 2                                  [Lost, Not accurate]    72.80    17.68
# 3                                       [Won, Accurate]    31.20    50.32
# 4                                                    []    71.76    16.32
# ...                                                 ...      ...      ...
# 1433                                         [Accurate]    70.72    23.12
# 1434                                         [Accurate]    81.12    48.96
# 1435                        [Left foot, High, Accurate]    93.60    49.64
# 1436  [Right foot, Opportunity, Position: Out low ri...    96.72    41.48
# 1437                                                 []     0.00    34.00
#
#        end_x  end_y
# 0      34.32  21.08
# 1      72.80  17.68
# 2      71.76  16.32
# 3      32.24  51.68
# 4        NaN    NaN
# ...      ...    ...
# 1433   81.12  48.96
# 1434   93.60  49.64
# 1435   96.72  41.48
# 1436  104.00  34.00
# 1437     NaN    NaN
#
# [1438 rows x 15 columns]

# %%
# 프랑스 기준, 내림차순으로 보는 경기 이벤트
counts = match_events.pivot_table('event_id', 'event_type', 'team_name', 'count', fill_value=0)
counts.sort_values('France', ascending=False)
# Out:
# team_name           Argentina  France
# event_type
# Pass                      486     335
# Duel                      168     179
# Others on the ball         49      68
# Free kick                  48      31
# Foul                       16      23
# Substitution                6       6
# Shot                        9       5
# Save attempt                4       4
# Offside                     1       0

# %%
pass_records = match_events[
    (match_events['event_type'] == 'Pass') |
    (match_events['sub_event_type'].isin(['Free kick', 'Free kick cross', 'corner']))
]
pass_records.head()
# Out:
#   match_id   event_id period    time team_id  team_name player_id  \
# 0  2058003  261065118     1H   1.303    4418     France      3682
# 1  2058003  261065119     1H   5.377    4418     France      3309
# 5  2058003  261065123     1H  45.823   12274  Argentina     90991
# 6  2058003  261065125     1H  49.247    4418     France      7936
# 7  2058003  261065126     1H  51.377    4418     France    353833
#
#     player_name event_type sub_event_type            tags  start_x  start_y  \
# 0  A. Griezmann       Pass    Simple pass      [Accurate]    52.00    34.00
# 1     R. Varane       Pass      High pass      [Accurate]    34.32    21.08
# 5     F. Armani  Free kick      Free kick  [Not accurate]    29.12    52.36
# 6      P. Pogba       Pass    Simple pass      [Accurate]    32.24    19.72
# 7     K. Mbappé       Pass    Simple pass      [Accurate]    35.36     8.84
#
#    end_x  end_y
# 0  34.32  21.08
# 1  72.80  17.68
# 5  71.76  48.28
# 6  35.36   8.84
# 7  23.92  11.56

# %%
acc_pass_records = pass_records[pass_records['tags'].apply(lambda x: 'Accurate' in x)]
acc_pass_records
# Out:
#      match_id   event_id period      time team_id  team_name player_id  \
# 0     2058003  261065118     1H     1.303    4418     France      3682
# 1     2058003  261065119     1H     5.377    4418     France      3309
# 6     2058003  261065125     1H    49.247    4418     France      7936
# 7     2058003  261065126     1H    51.377    4418     France    353833
# 8     2058003  261065127     1H    54.286    4418     France    340646
# ...       ...        ...    ...       ...     ...        ...       ...
# 1427  2058003  261066814     2H  2952.348    4418     France     25397
# 1432  2058003  261066779     2H  2984.332   12274  Argentina      3355
# 1433  2058003  261066780     2H   2988.34   12274  Argentina      3314
# 1434  2058003  261066781     2H   2990.99   12274  Argentina      8325
# 1435  2058003  261066783     2H  2993.545   12274  Argentina    146459
#
#         player_name event_type sub_event_type                         tags  \
# 0      A. Griezmann       Pass    Simple pass                   [Accurate]
# 1         R. Varane       Pass      High pass                   [Accurate]
# 6          P. Pogba       Pass    Simple pass                   [Accurate]
# 7         K. Mbappé       Pass    Simple pass                   [Accurate]
# 8         B. Pavard       Pass    Simple pass                   [Accurate]
# ...             ...        ...            ...                          ...
# 1427      S. Umtiti  Free kick      Free kick                   [Accurate]
# 1432  J. Mascherano       Pass      High pass                   [Accurate]
# 1433    Á. di María       Pass      High pass                   [Accurate]
# 1434      S. Agüero       Pass    Simple pass                   [Accurate]
# 1435        M. Meza       Pass          Cross  [Left foot, High, Accurate]
#
#       start_x  start_y   end_x  end_y
# 0       52.00    34.00   34.32  21.08
# 1       34.32    21.08   72.80  17.68
# 6       32.24    19.72   35.36   8.84
# 7       35.36     8.84   23.92  11.56
# 8       23.92    11.56    8.32  36.04
# ...       ...      ...     ...    ...
# 1427    63.44    47.60  102.96  57.12
# 1432    34.32    44.20   70.72  23.12
# 1433    70.72    23.12   81.12  48.96
# 1434    81.12    48.96   93.60  49.64
# 1435    93.60    49.64   96.72  41.48
#
# [732 rows x 15 columns]

# %%
# 패스 성공률 분석
total_pass_counts = pass_records['team_name'].value_counts().rename('total_passes')
acc_pass_counts = acc_pass_records['team_name'].value_counts().rename('acc_passes')
pass_counts = pd.concat([total_pass_counts, acc_pass_counts], axis=1)
pass_counts
# Out:
#            total_passes  acc_passes
# Argentina           502         432
# France              346         300

# %%
# 패스 정확도 분석
pass_counts['pass_accuracy'] = pass_counts['acc_passes'] / pass_counts['total_passes']
pass_counts
# Out:
#            total_passes  acc_passes  pass_accuracy
# Argentina           502         432       0.860558
# France              346         300       0.867052

# %%
# 전체 슈팅 횟수 및 유효슈팅 분석
shot_records = match_events[
    (match_events['event_type'] == 'Shot') |
    (match_events['sub_event_type'].isin(['Free kick shot', 'Penalty']))
]
acc_shot_records = shot_records[shot_records['tags'].apply(lambda x: 'Accurate' in x)]

total_shot_counts = shot_records['team_name'].value_counts().rename('total_shots')
acc_shot_counts = acc_shot_records['team_name'].value_counts().rename('shots_on_target')
shot_counts = pd.concat([total_shot_counts, acc_shot_counts], axis=1)
shot_counts
# Out:
#            total_shots  shots_on_target
# Argentina           10                4
# France               8                4

# %%
# 골 기록 분석
match_events[match_events['tags'].apply(lambda x: 'Goal' in x)]
# Out:
#      match_id   event_id period      time team_id  team_name player_id  \
# 180   2058003  261065352     1H    761.29    4418     France      3682
# 624   2058003  261065890     1H  2442.184   12274  Argentina      3314
# 757   2058003  261066818     2H   156.249   12274  Argentina     86220
# 864   2058003  261066161     2H   708.162    4418     France    340646
# 945   2058003  261066265     2H  1088.431    4418     France    353833
# 993   2058003  261066318     2H  1369.345    4418     France    353833
# 1411  2058003  261066745     2H  2823.552   12274  Argentina      8325
#
#        player_name event_type sub_event_type  \
# 180   A. Griezmann  Free kick        Penalty
# 624    Á. di María       Shot           Shot
# 757     G. Mercado       Shot           Shot
# 864      B. Pavard       Shot           Shot
# 945      K. Mbappé       Shot           Shot
# 993      K. Mbappé       Shot           Shot
# 1411     S. Agüero       Shot           Shot
#
#                                                    tags  start_x  start_y  \
# 180   [Goal, Left foot, Position: Goal low center, A...    92.56    35.36
# 624   [Goal, Left foot, Opportunity, Position: Goal ...    74.88    31.28
# 757   [Goal, Left foot, Interception, Opportunity, P...    96.72    30.60
# 864   [Goal, Right foot, Opportunity, Position: Goal...    85.28    17.00
# 945   [Goal, Left foot, Opportunity, Position: Goal ...    97.76    44.88
# 993   [Goal, Right foot, Opportunity, Position: Goal...    91.52    23.80
# 1411  [Goal, Head/body, Opportunity, Position: Goal ...    95.68    40.80
#
#       end_x  end_y
# 180   104.0   34.0
# 624   104.0   34.0
# 757   104.0   34.0
# 864   104.0   34.0
# 945   104.0   34.0
# 993   104.0   34.0
# 1411  104.0   34.0

# %%
# 자책골 분석
match_events[match_events['tags'].apply(lambda x: 'Own goal' in x)]
# Out:
# Empty DataFrame
# Columns: [match_id, event_id, period, time, team_id, team_name, player_id, player_name, event_type, sub_event_type, tags, start_x, start_y, end_x, end_y]
# Index: []

# %%
# 경기 점수 초기화
team_names = match_events['team_name'].unique()
goals = dict(zip(match_events['team_name'].unique(), [0, 0]))
goals
# Out:
# {'France': 0, 'Argentina': 0}

# %%
# 경기 점수 분석
goal_records = match_events[match_events['tags'].apply(lambda x: 'Goal' in x)]
for i, event in goal_records.iterrows():
    goals[event['team_name']] += 1

own_goal_records = match_events[match_events['tags'].apply(lambda x: 'Own goal' in x)]
for i, event in own_goal_records.iterrows():
    opponent_name = [team for team in team_names if team != event['team_name']][0]
    goals[opponent_name] += 1

goals
# Out:
# {'France': 4, 'Argentina': 3}

# %%
# 종합 경기 기록 산출
counts
# Out:
# team_name           Argentina  France
# event_type
# Duel                      168     179
# Foul                       16      23
# Free kick                  48      31
# Offside                     1       0
# Others on the ball         49      68
# Pass                      486     335
# Save attempt                4       4
# Shot                        9       5
# Substitution                6       6

# %%
# 파울, 오프사이드 횟수 분석
foul_counts = counts.T[['Foul', 'Offside']]
foul_counts.columns = ['fouls', 'offsides']
foul_counts
# Out:
#            fouls  offsides
# team_name
# Argentina     16         1
# France        23         0

# %%
# 경기 기록 분석
match_stats = pd.concat([pass_counts, shot_counts, foul_counts], axis=1)
match_stats
# Out:
#            total_passes  acc_passes  pass_accuracy  total_shots  \
# Argentina           502         432       0.860558           10
# France              346         300       0.867052            8
#
#            shots_on_target  fouls  offsides
# Argentina                4     16         1
# France                   4     23         0

# %%
# 골 기록 Series로 변환
pd.Series(goals)
# Out:
# France       4
# Argentina    3
# dtype: int64

# %%
# 중요 이벤트 기록 분석
match_stats['goals'] = pd.Series(goals)
match_stats = match_stats[[
    'goals', 'total_shots', 'shots_on_target',
    'fouls', 'offsides',
    'total_passes', 'acc_passes', 'pass_accuracy'
]]
match_stats
# Out:
#            goals  total_shots  shots_on_target  fouls  offsides  total_passes  \
# Argentina      3           10                4     16         1           502
# France         4            8                4     23         0           346
#
#            acc_passes  pass_accuracy
# Argentina         432       0.860558
# France            300       0.867052
